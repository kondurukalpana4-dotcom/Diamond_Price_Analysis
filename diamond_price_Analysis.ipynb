# %%
import pandas as pd

# %%
df=pd.read_csv("/content/diamonds.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.plot(kind="box")
# Out:
# <Axes: >

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440
# carat        -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094
# depth        -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289
# table        -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344
# price        -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435
# x            -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000
# y            -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701
# z            -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772
#
#                    y         z
# Unnamed: 0 -0.395843 -0.399208
# carat       0.951722  0.953387
# depth      -0.029341  0.094924
# table       0.183760  0.150929
# price       0.865421  0.861249
# x           0.974701  0.970772
# y           1.000000  0.952006
# z           0.952006  1.000000

# %%
df.select_dtypes(include="number").describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.mean(numeric_only=True)
# Out:
# Unnamed: 0    26970.500000
# carat             0.797940
# depth            61.749405
# table            57.457184
# price          3932.799722
# x                 5.731157
# y                 5.734526
# z                 3.538734
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Unnamed: 0    26970.50
# carat             0.70
# depth            61.80
# table            57.00
# price          2401.00
# x                 5.70
# y                 5.71
# z                 3.53
# dtype: float64

# %%
df.mode().iloc[0]
# Out:
# Unnamed: 0        1
# carat           0.3
# cut           Ideal
# color             G
# clarity         SI1
# depth          62.0
# table          56.0
# price         605.0
# x              4.37
# y              4.34
# z               2.7
# Name: 0, dtype: object

# %%
df.var(numeric_only=True)
# Out:
# Unnamed: 0    2.424648e+08
# carat         2.246867e-01
# depth         2.052404e+00
# table         4.992948e+00
# price         1.591563e+07
# x             1.258347e+00
# y             1.304472e+00
# z             4.980109e-01
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# Unnamed: 0    15571.281097
# carat             0.474011
# depth             1.432621
# table             2.234491
# price          3989.439738
# x                 1.121761
# y                 1.142135
# z                 0.705699
# dtype: float64

# %%
df["cut"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='cut'>

# %%
df.groupby("cut")["price"].mean().plot(kind="line")
# Out:
# <Axes: xlabel='cut'>

# %%
df["price"].plot(kind="hist",bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="scatter",x="carat",y="price")
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %% [markdown]
# Business Insight Report
#
# I loaded the Diamonds dataset and explored the data using Pandas. I checked the dataset information, column names, and statistical summary.
#
# I checked for missing values and duplicate records. There were no missing values and no duplicate records in the dataset. I also detected outliers using a box plot.
#
# I analyzed the categorical features ("cut", "color", and "clarity") and the numerical features ("carat", "price", "depth", "table", "x", "y", and "z"). I calculated the mean, median, mode, variance, and standard deviation for the numerical columns.
#
# I performed correlation analysis to understand the relationship between the numerical features. I created a bar chart, line chart, histogram, and scatter plot to visualize the data.
#
# Conclusion
#
# From this analysis, I observed that the carat of a diamond has a strong influence on its price. The cut, color, and clarity of a diamond also affect its value. This project helped me understand data cleaning, exploratory data analysis (EDA), statistical measures, correlation, and data visualization using Python, Pandas, and Matplotlib.
